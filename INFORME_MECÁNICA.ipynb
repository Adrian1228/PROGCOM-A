# %% [markdown]
# <a href="https://colab.research.google.com/github/Adrian1228/PROGCOM-A/blob/main/INFORME_MEC%C3%81NICA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as gra
print("Supongamos que se deja caer un cuerpo desde una altura (d), con un peso (p) y que termina con una velocidad final (vf). Ahora: ")
m = float(input("Ingresa la masa del cuerpo en Kilogramos (Kg): "))
Tto = float(input("Ingrese el tiempo de caída en segundos (s): "))

g = 10
p = m * g
vf = g * Tto
d= 0.5 * g * (Tto ** 2)

print("\n--- RESULTADOS ---")
print(f"Masa del cuerpo: {p} kg")
print(f"Velocidad final: {vf} m/s")
print(f"Distancia recorrida: {d} m")

t = [i * 0.1 for i in range(int(Tto * 10) + 1)]
x = [0.5 * g * (dis ** 2) for dis in t]

gra.plot(t, x, 'o-')
gra.title('Movimiento de caída libre')
gra.xlabel('Tiempo (s)')
gra.ylabel('Distancia (m)')
gra.grid(True) #Rejillas grises
gra.show() #Muestra gráfica
# Out:
# Supongamos que se deja caer un cuerpo desde una altura (d), con un peso (p) y que termina con una velocidad final (vf). Ahora:
# Ingresa la masa del cuerpo en Kilogramos (Kg): 55
# Ingrese el tiempo de caída en segundos (s): 10
#
# --- RESULTADOS ---
# Masa del cuerpo: 550.0 kg
# Velocidad final: 100.0 m/s
# Distancia recorrida: 500.0 m
